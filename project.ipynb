# %% [markdown]
# <a href="https://colab.research.google.com/github/Vandan1009/python_1/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-27.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Downloading Faker-27.0.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.4 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-27.0.0

# %%
from faker import Faker
fake = Faker()

# %%
print(fake.name())
# Out:
# James Ramirez

# %%
print(fake.email())
# Out:
# kristasanders@example.com

# %%
print(fake.country())
# Out:
# France

# %%
print(fake.country())
# Out:
# Samoa

# %%
print(fake.name())
# Out:
# Jeffery Reyes

# %%
print(fake.text())
# Out:
# Indeed effort everybody memory keep animal carry. Painting wear only ball audience.
# Word start personal. Door across plant especially bag dream citizen film. All education life.

# %%
print(fake.latitude(), fake.longitude())
# Out:
# 60.0310645 -40.113524

# %%
print(fake.url())
# Out:
# https://lee.com/

# %%
from random import randint
import pandas as pd
def input_data(x):

    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i,'product_id']= randint(1, 100)
        data.loc[i,'product_name']= fake.commerce.product_name()
        data.loc[i,'address']= fake.commerce.product_address()
        data.loc[i,'price']= randint(2000,30000)

    return data
input_data(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-5808f43dad52> in <cell line: 14>()
#      12
#      13     return data
# ---> 14 input_data(10)
#      15
#
# <ipython-input-27-5808f43dad52> in input_data(x)
#       7     for i in range(0, x):
#       8         data.loc[i,'product_id']= randint(1, 100)
# ----> 9         data.loc[i,'product_name']= fake.commerce.product_name()
#      10         data.loc[i,'address']= fake.commerce.product_address()
#      11         data.loc[i,'price']= randint(2000,30000)
#
# /usr/local/lib/python3.10/dist-packages/faker/proxy.py in __getattr__(self, attr)
#     128         """
#     129         if len(self._factories) == 1:
# --> 130             return getattr(self._factories[0], attr)
#     131         elif attr in self.generator_attrs:
#     132             msg = "Proxying calls to `%s` is not implemented in multiple locale mode." % attr
#
# AttributeError: 'Generator' object has no attribute 'commerce'

# %%
import pandas as pd
from random import randint, uniform, choice
from faker import Faker

fake = Faker()

def input_data(x):
    # List of product names for the accessories category
    accessories = ['belt', 'earring', 'glasses', 'glove', 'handbags', 'sun glasses', 'hat', 'watch', 'ring', 'necktie', 'helmet']

    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i, 'product_name'] = choice(accessories)
        data.loc[i, 'Price'] = round(uniform(10.0, 1000.0), 2)
        data.loc[i, 'Description'] = fake.sentence()
        data.loc[i, 'Category'] = 'accessories'
        data.loc[i, 'StockQuantity'] = randint(1, 100)
        data.loc[i, 'Brand'] = fake.company()
        data.loc[i, 'Rating'] = round(uniform(1.0, 5.0), 1)
        data.loc[i, 'Warehouse'] = fake.city()
    return data

# Example usage
input_data(10)
# Out:
#   product_name   Price                                        Description  \
# 0      glasses  782.44                      Physical message as personal.
# 1         ring  888.85                        Remain represent character.
# 2      earring  470.35                 Program door TV resource no speak.
# 3         belt  244.07                Scene arm learn knowledge old sort.
# 4  sun glasses  916.38                     Mission make when opportunity.
# 5      earring  751.32                          Receive born decision up.
# 6         belt  455.37  Service participant who center no late key com...
# 7        watch  793.25          Window exactly different very friend own.
# 8        glove  878.06           Sort thing adult rule include able they.
# 9        glove  287.24                               Player choice enter.
#
#       Category  StockQuantity                       Brand  Rating  \
# 0  accessories           57.0                 Miles-White     4.6
# 1  accessories           88.0               Rodriguez Inc     4.4
# 2  accessories           86.0  Fletcher, Hamilton and Cox     1.2
# 3  accessories           67.0               Hill-Roberson     1.4
# 4  accessories           42.0                 Patrick Inc     3.6
# 5  accessories           18.0               Gomez-Stewart     2.8
# 6  accessories           55.0                Weber-Carter     4.5
# 7  accessories            7.0                 Brennan Ltd     3.1
# 8  accessories           48.0  Jackson, Atkins and Watson     3.3
# 9  accessories           78.0                Kim and Sons     1.2
#
#          Warehouse
# 0      North Megan
# 1        North Amy
# 2  South Jamestown
# 3    East Brittney
# 4        Oscarport
# 5     Rebeccaburgh
# 6     Victoriaport
# 7   New Heatherton
# 8        West Paul
# 9      Andreaburgh

# %%
import pandas as pd
from random import randint, uniform, choice
from faker import Faker

fake = Faker()

def input_data(x):
    # List of product names for the accessories category
    accessories = ['Belt','Earring','Glasses','Glove','Handbag','Hat','Helmet','Necktie','Perfume','Ring','Sash','Sunglasses','Umbrella','Watch','Anklets','Bangles and Bracelets','Brooches and Pins','Cuff Links and Studs','Hair Accessories','Handkerchiefs and Pocket Squares','Luggage','Necklaces and Pendants','Wallets']

    # List of brand names for the accessories category
    brands = ['Gucci','Fossil', 'Prada','Kate Spade','Tory Burch','Bvlgari','Cartier','Swarovski','Ray-Ban','Oakley', 'Louis Vuitton', 'Chanel','Michael Kors','Coach', 'Hermes', 'Fendi', 'Balenciaga', 'Dior', 'Versace', 'Burberry']

    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i, 'product_name'] = choice(accessories)
        data.loc[i, 'Price'] = round(uniform(100.0, 10000.0), 2)
        data.loc[i, 'Description'] = fake.sentence()
        data.loc[i, 'Category'] = 'accessories'
        data.loc[i, 'StockQuantity'] = randint(1, 100)
        data.loc[i, 'Brand'] = choice(brands)
        data.loc[i, 'Rating'] = round(uniform(1.0, 5.0), 1)
        data.loc[i, 'Warehouse'] = fake.city()
    return data

# Example usage
input_data(10)
# Out:
#                        product_name    Price  \
# 0                               Hat  8196.20
# 1                           Perfume  6622.09
# 2             Bangles and Bracelets   316.40
# 3                           Earring  3764.93
# 4  Handkerchiefs and Pocket Squares  7380.65
# 5                          Umbrella  4307.06
# 6  Handkerchiefs and Pocket Squares  8738.69
# 7                            Helmet  5123.89
# 8  Handkerchiefs and Pocket Squares  9697.82
# 9                  Hair Accessories  3676.11
#
#                                        Description     Category  \
# 0         Well of I level and size that professor.  accessories
# 1                                Class PM exactly.  accessories
# 2                          Cut a structure father.  accessories
# 3                Sense others service notice once.  accessories
# 4                     Window they even think huge.  accessories
# 5    Necessary drug catch event paper summer wall.  accessories
# 6  Officer ago huge indeed management fill really.  accessories
# 7  Tend subject teach reason enough dog by doctor.  accessories
# 8            Wall four both society author detail.  accessories
# 9                      Upon prove real movie land.  accessories
#
#    StockQuantity          Brand  Rating           Warehouse
# 0           99.0        Ray-Ban     3.4     Port Amandafurt
# 1           38.0        Versace     4.3  South Williammouth
# 2            7.0        Versace     3.4      New Donborough
# 3           23.0       Burberry     1.3         South Kevin
# 4           61.0     Tory Burch     1.6   North Matthewfurt
# 5           68.0  Louis Vuitton     3.4      Fernandezmouth
# 6           72.0   Michael Kors     1.3        East Michael
# 7           26.0        Versace     2.3       Christinestad
# 8           79.0        Bvlgari     4.3           New Aaron
# 9           42.0         Chanel     2.7    South Jeffreyton

# %%
import pandas as pd
from random import randint, uniform, choice
from faker import Faker

fake = Faker()

# List of book categories
book_categories = [
    "Fantasy", "Science Fiction", "Mystery", "Horror", "Historical Fiction", "Women’s Fiction",
    "Literary Fiction", "Magic Realism", "Graphic Novel", "Short Story", "Young Adult", "New Adult",
    "Dystopian", "Action & Adventure", "Thriller & Suspense", "Romance", "Children’s", "Contemporary Fiction",
    "Biography", "Self-Help", "History", "Memoir & Autobiography", "Food & Drink", "Art & Photography", "Travel"
]

def input_data(x):
    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i, 'product_name'] = choice(book_categories)
        data.loc[i, 'Price'] = round(uniform(100.0, 4000.0), 2)
        data.loc[i, 'Description'] = fake.sentence()
        data.loc[i, 'Category'] = 'Books'
        data.loc[i, 'StockQuantity'] = randint(1, 100)
        data.loc[i, 'Brand'] = fake.company()
        data.loc[i, 'Rating'] = round(uniform(1.0, 5.0), 1)
        data.loc[i, 'Warehouse'] = fake.city()
        print(data.info())
    return data

# Example usage
input_data(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name
non-null     object
# dtypes: float64(3), object(5)
# memory usage: 1020.0+ bytes
# None
#              product_name    Price  \
# 0                  Travel  3489.63
# 1             Young Adult  3231.98
# 2     Thriller & Suspense  1052.90
# 3  Memoir & Autobiography  2428.19
# 4                 Fantasy  3692.51
# 5               Self-Help  1701.62
# 6           Graphic Novel  2067.81
# 7         Science Fiction  3948.83
# 8            Food & Drink   487.00
# 9        Literary Fiction  2924.62
#
#                                          Description Category  StockQuantity  \
# 0                             Small those try value.    Books           69.0
# 1                             Likely under yet sing.    Books           40.0
# 2                     Along poor agreement describe.    Books           95.0
# 3             Subject must director far age message.    Books           45.0
# 4               Successful moment oil action create.    Books           34.0
# 5                         Control country president.    Books           87.0
# 6  Beat fall pressure radio sister check discover...    Books           63.0
# 7                              Than pass each under.    Books           34.0
# 8                       Choose measure drive pretty.    Books           35.0
# 9    News common exactly final fine parent positive.    Books           84.0
#
#                         Brand  Rating            Warehouse
# 0       Drake, May and Gibson     3.1           Port Henry
# 1                   Brown Inc     3.9  East Christineburgh
# 2                    Chan Ltd     2.6        North Melanie
# 3  Wilson, Wilson and Wheeler     4.7    West Kathleenland
# 4                 Graham-Hill     2.4            Scottstad
# 5                  Huerta PLC     1.8          Cynthiaport
# 6                  Ball-Kline     3.2        East Jayhaven
# 7                Swanson-Soto     2.2          Kristenstad
# 8                Brown-Gentry     3.7          North Raven
# 9     Berg, Ramirez and Jones     1.2           Port Katie

# %%
import pandas as pd
from random import randint, uniform, choice
from faker import Faker

fake = Faker()

# List of book categories
book_categories = [
    "Fantasy", "Science Fiction", "Mystery", "Horror", "Historical Fiction", "Women’s Fiction",
    "Literary Fiction", "Magic Realism", "Graphic Novel", "Short Story", "Young Adult", "New Adult",
    "Dystopian", "Action & Adventure", "Thriller & Suspense", "Romance", "Children’s", "Contemporary Fiction",
    "Biography", "Self-Help", "History", "Memoir & Autobiography", "Food & Drink", "Art & Photography", "Travel"
]

def input_data(x):
    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i, 'product_name'] = choice(book_categories)
        data.loc[i, 'Price'] = round(uniform(10.0, 1000.0), 2)
        data.loc[i, 'Description'] = fake.sentence()
        data.loc[i, 'Category'] = 'Books'
        data.loc[i, 'Author'] = fake.name()
        data.loc[i, 'StockQuantity'] = randint(1, 100)
        data.loc[i, 'Brand'] = fake.company()
        data.loc[i, 'Rating'] = round(uniform(1.0, 5.0), 1)
        data.loc[i, 'Warehouse'] = fake.city()
    return data

# Example usage
input_data(10)
# Out:
#              product_name   Price  \
# 0    Contemporary Fiction   36.35
# 1               Biography  848.28
# 2           Magic Realism  795.58
# 3                 Mystery  425.18
# 4               Self-Help  344.44
# 5               New Adult  457.69
# 6                 Fantasy  227.58
# 7      Historical Fiction  620.39
# 8  Memoir & Autobiography  688.53
# 9                 History  580.14
#
#                                        Description Category            Author  \
# 0                    Though thousand again within.    Books         David Lee
# 1            Result drive until cost dinner state.    Books        Michael Li
# 2                         Plan level same partner.    Books  Christina Wilson
# 3              Room throughout order you continue.    Books     Jesse Simmons
# 4                       Improve front theory film.    Books  Jennifer Johnson
# 5                       Option may fish writer it.    Books   Angela Morrison
# 6                    Race hundred until foot five.    Books       Joshua Frye
# 7                               Mean when TV only.    Books      James Garcia
# 8  Teacher plant record hotel step simple address.    Books    Victoria Yates
# 9                 Various expert customer popular.    Books   Stephanie Costa
#
#    StockQuantity                           Brand  Rating         Warehouse
# 0           14.0               Shepherd-Martinez     3.8  West Michaelbury
# 1           42.0               Martinez-Valencia     1.2        Gilbertton
# 2           88.0   Thompson, Robinson and Miller     3.6     Justinchester
# 3           56.0                  Hawkins-Turner     1.4     Lake Sheriton
# 4           76.0                   Booker-Hudson     3.9        Port Debra
# 5           73.0        Lewis, Stewart and Brady     4.9    West Larryview
# 6           65.0  Oconnell, Gonzales and Barrett     2.9       West Teresa
# 7           80.0     Brooks, Olson and Dominguez     4.5       Darrellview
# 8           77.0        Price, Miller and Deleon     3.8          Sheaview
# 9            2.0        Nelson, Singh and Hebert     1.4        East Donna
